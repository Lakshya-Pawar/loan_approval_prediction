# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("Training Dataset.csv")

# %%
train_df_main = train_df.copy()

# %%
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train_df.shape
# Out:
# (614, 13)

# %%
train_df.groupby('Property_Area')['Loan_Status'].value_counts()
# Out:
# Property_Area  Loan_Status
# Rural          Y              110
#                N               69
# Semiurban      Y              179
#                N               54
# Urban          Y              133
#                N               69
# Name: count, dtype: int64

# %%
train_df.groupby('Dependents')['Loan_Status'].value_counts()
# Out:
# Dependents  Loan_Status
# 0           Y              238
#             N              107
# 1           Y               66
#             N               36
# 2           Y               76
#             N               25
# 3+          Y               33
#             N               18
# Name: count, dtype: int64

# %%
train_df['Dependents'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train_df.groupby('Self_Employed')['Loan_Status'].value_counts()
# Out:
# Self_Employed  Loan_Status
# No             Y              343
#                N              157
# Yes            Y               56
#                N               26
# Name: count, dtype: int64

# %%
train_df['Self_Employed'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['LoanAmount'].fillna(train_df['LoanAmount'].median(), inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\3744298454.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['LoanAmount'].fillna(train_df['LoanAmount'].median(), inplace=True)

# %%
sns.histplot(x=train_df['LoanAmount'], kde=True)
plt.show()

# %%
sns.histplot(x=train_df['Loan_Amount_Term'], kde=True)
plt.show()

# %%
train_df['Loan_Amount_Term'].fillna(train_df['Loan_Amount_Term'].median(), inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\886472946.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Loan_Amount_Term'].fillna(train_df['Loan_Amount_Term'].median(), inplace=True)

# %%
train_df['Credit_History'].fillna(train_df['Credit_History'].mode()[0], inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\1009487812.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Credit_History'].fillna(train_df['Credit_History'].mode()[0], inplace=True)

# %%
train_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df.shape
# Out:
# (614, 13)

# %%
train_df['Gender'].fillna(train_df['Gender'].mode()[0], inplace=True)
train_df['Married'].fillna(train_df['Married'].mode()[0], inplace=True)
train_df['Dependents'].fillna(train_df['Dependents'].mode()[0], inplace=True)
train_df['Self_Employed'].fillna(train_df['Self_Employed'].mode()[0], inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\2266060628.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Gender'].fillna(train_df['Gender'].mode()[0], inplace=True)
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\2266060628.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
train_df.shape
# Out:
# (614, 13)

# %%
train_df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train_df.groupby('Dependents')['Loan_Status'].value_counts()
# Out:
# Dependents  Loan_Status
# 0           Y              247
#             N              113
# 1           Y               66
#             N               36
# 2           Y               76
#             N               25
# 3+          Y               33
#             N               18
# Name: count, dtype: int64

# %%
train_df['Dependents'] = train_df['Dependents'].replace('3+', '3')

# %%
train_df.groupby('Dependents')['Loan_Status'].value_counts()
# Out:
# Dependents  Loan_Status
# 0           Y              247
#             N              113
# 1           Y               66
#             N               36
# 2           Y               76
#             N               25
# 3           Y               33
#             N               18
# Name: count, dtype: int64

# %%
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
test = pd.read_csv("formulated_test.csv")

# %%
test.shape
# Out:
# (367, 12)

# %%
train_df = pd.concat([train_df, test], axis=0)

# %%
train_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes          3  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# ...

# %%
def grab_col_names(dataframe, cat_th=10, car_th=20):

    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and dataframe[col].dtypes != "O"]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and dataframe[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O" and col not in num_but_cat]

    print(f"Observations: {dataframe.shape[0]}")
    print(f"Variables: {dataframe.shape[1]}")
    print(f"cat_cols: {len(cat_cols)}")
    print(f"num_cols: {len(num_cols)}")
    print(f"cat_but_car: {len(cat_but_car)}")
    print(f"num_but_cat: {len(num_but_cat)}")

    return cat_cols, num_cols, cat_but_car

# %%
grab_col_names(train_df)
# Out:
# Observations: 981
# Variables: 13
# cat_cols: 8
# num_cols: 4
# cat_but_car: 1
# num_but_cat: 1
# (['Gender',
#   'Married',
#   'Dependents',
#   'Education',
#   'Self_Employed',
#   'Property_Area',
#   'Loan_Status',
#   'Credit_History'],
#  ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term'],
#  ['Loan_ID'])

# %%
train_df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
train_df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    833
# 0.0    148
# Name: count, dtype: int64

# %%
train_df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    349
# Urban        342
# Rural        290
# Name: count, dtype: int64

# %%
train_df['Education'].value_counts()
# Out:
# Education
# Graduate        763
# Not Graduate    218
# Name: count, dtype: int64

# %%
train_df.shape
# Out:
# (981, 13)

# %%
train_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes          3  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# ...

# %%
def outlier_thresholds(dataframe, col_name, q1=0.25, q3=0.75):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquartile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquartile_range
    low_limit = quartile1 - 1.5 * interquartile_range
    return low_limit, up_limit

def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name]>up_limit) | (dataframe[col_name]<low_limit)].any(axis=None):
        return True
    else:
        return False

# %%
check_outlier(train_df, 'ApplicantIncome')
# Out:
# True

# %%
sns.boxplot(x=train_df['ApplicantIncome'])
plt.show()

# %%
def replace_with_thresholds(dataframe, variable):
    low_limit, up_limit = outlier_thresholds(dataframe, variable)
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit

# %%
replace_with_thresholds(train_df, 'ApplicantIncome')
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\130684917.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-1086.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 981 entries, 0 to 366
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             981 non-null    object
#  2   Married            981 non-null    object
#  3   Dependents         981 non-null    object
#  4   Education          981 non-null    object
#  5   Self_Employed      981 non-null    object
#  6   ApplicantIncome    981 non-null    float64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         981 non-null    float64
#  9   Loan_Amount_Term   981 non-null    float64
#  10  Credit_History     981 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 107.3+ KB

# %%
check_outlier(train_df, 'ApplicantIncome')
# Out:
# False

# %%
sns.boxplot(x=train_df['ApplicantIncome'])
plt.show()

# %%
check_outlier(train_df, 'CoapplicantIncome')
# Out:
# True

# %%
replace_with_thresholds(train_df, 'CoapplicantIncome')

# %%
check_outlier(train_df, 'CoapplicantIncome')
# Out:
# False

# %%
sns.boxplot(x=train_df['CoapplicantIncome'])
plt.show()

# %%
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0       128.0             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
train_df['Gender'] = LE.fit_transform(train_df['Gender'])
train_df['Married'] = LE.fit_transform(train_df['Married'])
train_df['Education'] = LE.fit_transform(train_df['Education'])
train_df['Self_Employed'] = LE.fit_transform(train_df['Self_Employed'])

# %%
train_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          3          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# ...

# %%
train_df['Loan_Status'] = train_df['Loan_Status'].replace('Y', '1')
train_df['Loan_Status'] = train_df['Loan_Status'].replace('N', '0')

# %%
train_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          3          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# ...

# %%
train_df['Gender'].value_counts()
# Out:
# Gender
# 1    799
# 0    182
# Name: count, dtype: int64

# %%
columns = ['Property_Area']

# %%
len(columns)
# Out:
# 1

# %%
def category_onehot_multcols(multcolumns):
    df_final=train_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(train_df[fields]).astype(int)
        
        train_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([train_df,df_final],axis=1)
        
    return df_final

# %%
train_df = category_onehot_multcols(columns)
# Out:
# Property_Area

# %%
train_df.shape
# Out:
# (981, 15)

# %%
train_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          3          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# ...

# %%
train_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Loan_Status', 'Rural',
#        'Semiurban', 'Urban'],
#       dtype='object')

# %%
len(train_df[train_df.duplicated()])
# Out:
# 0

# %%
train_df_formulated = train_df.copy()

# %%
train_df.shape
# Out:
# (981, 15)

# %%
df_Train=train_df.iloc[:614,:]
df_Test=train_df.iloc[614:,:]

# %%
df_Train.shape
# Out:
# (614, 15)

# %%
df_Train
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1          3          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849.0                0.0       128.0             360.0
# ...

# %%
df_Test.shape
# Out:
# (367, 15)

# %%
df_Test
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          3          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720.0                0.0       110.0             360.0
# ...

# %%
df_Test_main = df_Test.copy()

# %%
df_Test.drop(['Loan_Status'],axis=1,inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\2410690061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Test.drop(['Loan_Status'],axis=1,inplace=True)

# %%
df_Test.shape
# Out:
# (367, 14)

# %%
df_Train.drop('Loan_ID', axis=1, inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\4219813617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Train.drop('Loan_ID', axis=1, inplace=True)

# %%
df_Train.shape
# Out:
# (614, 14)

# %%
df_Train.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          0              0           5849.0
# 1       1        1          1          0              0           4583.0
# 2       1        1          0          0              1           3000.0
# 3       1        1          0          1              0           2583.0
# 4       1        0          0          0              0           6000.0
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Loan_Status  Rural  Semiurban  Urban
# 0           1      0          0      1
# 1           0      1          0      0
# ...

# %%
X = df_Train.drop('Loan_Status', axis=1)
y = df_Train['Loan_Status']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
X_train.shape
# Out:
# (368, 13)

# %%
X_train
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 332       1        0          0          0              0           2833.0
# 320       1        1          0          0              0           2400.0
# 49        0        0          0          0              0           4000.0
# 274       1        1          2          0              0           3900.0
# 25        1        1          0          0              1           9477.5
# ..      ...      ...        ...        ...            ...              ...
# 71        1        1          2          1              1           1875.0
# 106       1        1          2          0              0           9477.5
# 270       0        0          0          0              0           3237.0
# 435       0        1          0          0              0           9477.5
# 102       1        1          0          0              0           9477.5
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = scaler.fit_transform(X_train[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])

# %%
X_train.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 332       1        0   -0.716062          0              0        -0.764277
# 320       1        1   -0.716062          0              0        -0.944732
# 49        0        0   -0.716062          0              0        -0.277922
# 274       1        1    1.272699          0              0        -0.319598
# 25        1        1   -0.716062          0              1         2.004860
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Rural  \
# 332          -0.829457   -0.868521          0.296646             1.0      0
# 320           0.461780   -0.358342          0.296646             1.0      0
# 49            0.526134   -0.022087          0.296646             1.0      0
# 274          -0.829457   -0.648216          0.296646             1.0      0
# 25           -0.829457    0.522877          0.296646             1.0      0
#
#      Semiurban  Urban
# 332          0      1
# ...

# %%
X_test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = scaler.transform(X_test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])

# %%
X_test.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 350       1        1   -0.716062          0              0         1.840450
# 377       1        1   -0.716062          0              0        -0.148728
# 163       1        1    1.272699          0              0        -0.208324
# 609       0        0   -0.716062          0              0        -0.736354
# 132       1        0   -0.716062          0              0        -0.812204
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Rural  \
# 350          -0.829457    0.951892          0.296646             1.0      0
# 377          -0.829457   -0.184417          0.296646             1.0      0
# 163           0.032758    0.140243          0.296646             1.0      1
# 609          -0.829457   -0.868521          0.296646             1.0      1
# 132          -0.829457   -0.880116          0.296646             1.0      0
#
#      Semiurban  Urban
# 350          1      0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
y_pred = model_1.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# np.float64(0.1691158395437114)

# %%
model_2 = RandomForestRegressor(n_estimators=100)
model_2.fit(X_train, y_train)
y_pred = model_2.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# np.float64(0.15950528455284557)

# %%
from sklearn.linear_model import Ridge

model_3 = Ridge(alpha=1.0)
model_3.fit(X_train, y_train)
y_pred = model_3.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# np.float64(0.1693339738294436)

# %%
df_Test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = scaler.transform(df_Test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\3797649541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']] = scaler.transform(df_Test[['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']])

# %%
df_Test.drop('Loan_ID', axis=1, inplace=True)
# Out:
# C:\Users\Lakshya Pawar\AppData\Local\Temp\ipykernel_13332\3021493233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Test.drop('Loan_ID', axis=1, inplace=True)

# %%
pred = model_2.predict(df_Test)
final = pd.DataFrame()
final['Loan_ID'] = df_Test_main['Loan_ID']
final['Loan_Status'] = pred
final
# Out:
#       Loan_ID  Loan_Status
# 0    LP001015         0.86
# 1    LP001022         0.90
# 2    LP001031         0.95
# 3    LP001035         0.92
# 4    LP001051         0.74
# ..        ...          ...
# 362  LP002971         0.87
# 363  LP002975         0.94
# 364  LP002980         0.92
# 365  LP002986         0.82
# 366  LP002989         0.68
#
# [367 rows x 2 columns]

# %%
final['Loan_Status'] = final['Loan_Status'].apply(lambda x: 1 if x >= 0.5 else 0)

# %%
final
# Out:
#       Loan_ID  Loan_Status
# 0    LP001015            1
# 1    LP001022            1
# 2    LP001031            1
# 3    LP001035            1
# 4    LP001051            1
# ..        ...          ...
# 362  LP002971            1
# 363  LP002975            1
# 364  LP002980            1
# 365  LP002986            1
# 366  LP002989            1
#
# [367 rows x 2 columns]

# %%
final['Loan_Status'] = final['Loan_Status'].replace({1: 'Y', 0: 'N'})

# %%
final
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
final['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    303
# N     64
# Name: count, dtype: int64

# %%
final['Loan_Status'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
final.to_csv('loan_status_predicted.csv', index=False)
